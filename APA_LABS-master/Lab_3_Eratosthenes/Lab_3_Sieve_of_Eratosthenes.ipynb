# %% [markdown]
# # Lab 3

# %% [markdown]
# ### import libraries

# %%
import math as m
import time
import matplotlib.pyplot as plt
from tabulate import tabulate

# %%
ex_time_list = []

# %%
list_n = [1000, 1500, 2000, 2500, 5000, 10000, 15000, 20000, 50000, 100000, 500000, 1000000]

# %% [markdown]
# ## Algorithm 1

# %%
def sieve_of_eratosthenes_1(n):
    c = [True] * (n + 1)
    c[0], c[1] = False, False

    i = 2
    while i <= n:
        if c[i]:
            j = 2 * i
            while j <= n:
                c[j] = False
                j += i
        i += 1

    primes = []
    for i in range(2, n + 1):
        if c[i]:
            primes.append(i)

    return primes

# %% [markdown]
# ## Algorithm 2

# %%
def sieve_of_eratosthenes_2(n):
    c = [True] * (n + 1)
    c[0], c[1] = False, False

    i = 2
    while i <= n:
        j = 2 * i
        while j <= n:
            c[j] = False
            j += i
        i += 1

    primes = []
    for i in range(2, n + 1):
        if c[i]:
            primes.append(i)

    return primes

# %% [markdown]
# ## Algorithm 3

# %%
def sieve_of_eratosthenes_3(n):
    C = [True] * (n+1)
    C[1] = False
    i = 2
    while i <= n:
        if C[i]:
            j = i + 1
            while j <= n:
                if j % i == 0:
                    C[j] = False
                j = j + 1
        i = i + 1
    
    return [ind for ind, val in enumerate(C) if C[ind] == True]

# %% [markdown]
# ## Algorithm 4

# %%
def sieve_of_eratosthenes_4(n):
    c = [True] * (n + 1)
    c[0], c[1] = False, False

    i = 2
    while i <= n:
        j = 1
        while j < i:
            if i % j == 0:
                c[i] = False
                break
            j += 1
        i += 1

    primes = []
    for i in range(2, n + 1):
        if c[i]:
            primes.append(i)

    return primes

# %% [markdown]
# ## Algorithm 5

# %%
def sieve_of_eratosthenes_5(n):
    c = [True] * (n + 1)
    c[0], c[1] = False, False

    i = 2
    while i <= n:
        j = 2
        while j <= m.sqrt(i):
            if i % j == 0:
                c[i] = False
                break
            j += 1
        i += 1

    primes = []
    for i in range(2, n + 1):
        if c[i]:
            primes.append(i)

    return primes

# %%
algorithm_list = ['sieve_of_eratosthenes_1', 'sieve_of_eratosthenes_2', 'sieve_of_eratosthenes_3', 'sieve_of_eratosthenes_4', 'sieve_of_eratosthenes_5']

# %%
headers=['Sieve of Eratosthenes term number',  'Execution time(wall time)', 'Execution time(CPU time)']

# %%
k = 1
list_ex = []
for alg in algorithm_list:
    table = []
    for i in list_n:
        """
        loop for calculating the execution time
        and including the results in a table
        """
        start = time.time()
        start2 = time.process_time()
        nr = sieve_of_eratosthenes_1(i)
        end = time.time()
        end2 = time.process_time()
        # time in milliseconds
        ex_time = (end - start) * 1000
        ex_time_list.append(ex_time)
        ex_time2 = (end2 - start2) * 1000
        table.append([i, ex_time, ex_time2])

    print(f'Algorithm {k}')
    print(tabulate(table, headers=headers, tablefmt='fancy_grid'))
    t = [el[1] for el in table]
    list_ex.append(list(t))
    plt.plot(list_n, list_ex[0], '-og')
    plt.xlabel("array length")
    plt.ylabel("execution time (milliseconds)")
    plt.title(f"Algorithm {k}")
    plt.ticklabel_format(useOffset=False, style='plain')
    plt.show()
    k +=1

plt.figure(figsize=(20, 20))
plt.plot(list_n, list_ex[0], '-ob', label="Algorithm 1")
plt.plot(list_n, list_ex[1], '-om', label="Algorithm 2")
plt.plot(list_n, list_ex[2], '-oy', label="Algorithm 3")
plt.plot(list_n, list_ex[3], '-og', label="Algorithm 4")
plt.plot(list_n, list_ex[4], '-oc', label="Algorithm 5")
plt.legend(['Algorithm 1', 'Algorithm 2', 'Algorithm 3', 'Algorithm 4', 'Algorithm 5'])
plt.xlabel("array length")
plt.ylabel("execution time (milliseconds)")
plt.title("All Algorithms")
plt.ticklabel_format(useOffset=False, style='plain')
plt.show()
# Out:
# Algorithm 1
# ╒═════════════════════════════════════╤═════════════════════════════╤════════════════════════════╕
# │   Sieve of Eratosthenes term number │   Execution time(wall time) │   Execution time(CPU time) │
# ╞═════════════════════════════════════╪═════════════════════════════╪════════════════════════════╡
# │                                1000 │                    0.947237 │                      0     │
# ├─────────────────────────────────────┼─────────────────────────────┼────────────────────────────┤
# │                                1500 │                    0.994682 │                      0     │
# ├─────────────────────────────────────┼─────────────────────────────┼────────────────────────────┤
# │                                2000 │                    0        │                      0     │
# ├─────────────────────────────────────┼─────────────────────────────┼────────────────────────────┤
# ...

# %%
sieve_of_eratosthenes_5(15)
# Out:
# [2, 3, 5, 7, 11, 13]

# %%
exec_time_3 = []
for value in list_n:
    start_time = time.time()
    vals = sieve_of_eratosthenes_3(value)
    exec_time_3.append(time.time() - start_time)

plt.plot(list_n, exec_time_3)
plt.xlabel("array length")
plt.ylabel("time (seconds)")
plt.show()

table = pd.DataFrame(data=list_n, columns=['length'])
table['time (seconds)'] = exec_time_3
print(table)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8928\2027978753.py in <module>
#       2 for value in list_n:
#       3     start_time = time.time()
# ----> 4     vals = sieve_of_eratosthenes_3(value)
#       5     exec_time_3.append(time.time() - start_time)
#       6
#
# ~\AppData\Local\Temp\ipykernel_8928\1707876417.py in sieve_of_eratosthenes_3(n)
#       9                 if j % i == 0:
#      10                     C[j] = False
# ---> 11                 j = j + 1
#      12         i = i + 1
#      13
#
# KeyboardInterrupt:
