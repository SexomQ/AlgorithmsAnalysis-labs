# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import deque
import random as r
import time as tm

# %% [markdown]
# ### Initiate the trees

# %%
# define a graph using adjacency list
balanced_tree = {
    'A': ['D', 'E'],
    'B': ['F', 'G'],
    'C': ['H', 'I', 'J'],
    'D': [],
    'E': ['K', 'L'],
    'F': ['M', 'N'],
    'G': [],
    'H': [],
    'I': ['O', 'P', 'Q'],
    'J': ['R'],
    'K': [],
    'L': [],
    'M': [],
    'N': [],
    'O': [],
    'P': [],
    'Q': [],
    'R': [],
    'S': ['A', 'B', 'C']
}

unbalanced_tree = {
    'A': ['D'],
    'B': ['H', 'I'],
    'C': ['F', 'G'],
    'D': ['E'],
    'E': [],
    'F': [],
    'G': [],
    'H': ['K', 'L'],
    'I': ['M', 'N', 'O'],
    'J': ['P', 'Q'],
    'K': ['R', 'J'],
    'L': [],
    'M': [],
    'N': [],
    'O': [],
    'P': [],
    'Q': [],
    'R': [],
    'S': ['A', 'B', 'C']
}

nodes = list(balanced_tree)

# %%
test_tree = {
  'A': ['D', 'E', 'V'],
  'B': ['F', 'G'],
  'C': ['H', 'I', 'J'],
  'D': ['W', 'X', 'AA', 'BB'],
  'E': ['K', 'L', 'Y', 'AB'],
  'F': ['M', 'N', 'AC'],
  'G': ['Z', 'AD', 'BC'],
  'H': ['AE', 'AF', 'BD'],
  'I': ['O', 'P', 'Q', 'AG', 'BE'],
  'J': ['R', 'S', 'AH', 'BF'],
  'K': ['AI', 'BG'],
  'L': ['T', 'AJ', 'BH'],
  'M': ['U', 'AK', 'BI'],
  'N': ['AL', 'BJ'],
  'O': ['AM', 'BK'],
  'P': ['BL'],
  'Q': ['AN', 'BM'],
  'R': ['AO', 'BN'],
  'S': ['AP', 'BO'],
  'T': ['AQ', 'BP'],
  'U': ['BR'],
  'V': ['AR', 'BS'],
  'W': ['BT'],
  'X': ['BU'],
  'Y': ['AS', 'AT', 'BV'],
  'Z': ['AU', 'BW'],
  'AA': ['BX'],
  'AB': ['AV', 'BY'],
  'AC': ['BZ'],
  'AD': ['CA'],
  'AE': ['CB'],
  'AF': ['CC'],
  'AG': ['CD'],
  'AH': ['CE'],
  'AI': ['CF'],
  'AJ': ['CG'],
  'AK': ['CH'],
  'AL': ['CI'],
  'AM': ['CJ'],
  'AN': ['CK'],
  'AO': ['CL'],
  'AP': ['CM'],
  'AQ': ['CN'],
  'AR': ['CO'],
  'AS': ['CP'],
  'AT': ['CQ'],
  'AU': ['CR'],
  'AV': ['CS'],
  'AW': ['CT'],
  'AX': ['CU'],
  'AY': ['CV'],
  'AZ': ['CW'],
  'BA': ['CX'],
  'BB': [],
  'BC': [],
  'BD': [],
  'BE': [],
  'BF': [],
  'BG': [],
  'BH': [],
  'BI': [],
  'BJ': [],
  'BK': [],
  'BL': [],
  'BM': [],
  'BN': [],
  'BO': [],
  'BP': [],
  'BQ': [],
  'BR': [],
  'BS': [],
  'BT': [],
  'BU': [],
  'BV': [],
  'BW': [],
  'BX': [],
  'BY': [],
  'BZ': [],
  'CA': [],
  'CB': [],
  'CC': [],
  'CD': [],
  'CE': [],
  'CF': [],
  'CG': [],
  'CH': [],
  'CI': [],
  'CJ': [],
  'CK': [],
  'CL': [],
  'CM': [],
  'CN': [],
  'CO': [],
  'CP': [],
  'CQ': [],
  'CR': [],
  'CS': [],
  'CT': [],
  'CU': [],
  'CV': [],
  'CW': [],
  'CX': []
}
nodes_test = list(test_tree)

# %% [markdown]
# ### Implementation of the algorithms (DFS and BFS)

# %%
# The DFS algorithm
def dfs(st_node, fin_node, tree):
    visited = set()  # keep track of visited nodes

    def dfs_alg(node, end_node):
        visited.add(node)
        # print(node, end=' ')
        if node == end_node:
            return True

        for neighbor in tree[node]:
            if neighbor not in visited:
                if dfs_alg(neighbor, end_node):
                    return True

        return False

    if dfs_alg(st_node, fin_node):
        return True
    else: return False

# The BFS algorithm
def bfs(st_node, fin_node, tree):
    visited = set()  # keep track of visited nodes
    queue = deque([st_node])  # initialize queue with start node

    while queue:
        node = queue.popleft()
        # print(node, end=' ')
        if node == fin_node:
            return True

        visited.add(node)
        for neighbor in tree[node]:
            if neighbor not in visited:
                queue.append(neighbor)

    return False

# %%
dfs('S', 'J', balanced_tree)
# Out:
# True

# %%
bfs('S', 'J', balanced_tree)
# Out:
# True

# %% [markdown]
# ### Get nodes to find for dfs and bfs

# %%
find_nodes = r.sample(nodes, 10)

# %% [markdown]
# ### Run dfs and bfs on the balanced tree

# %%
exec_time_dfs_bt = []
no_of_nodes = range(1, len(find_nodes)+1)

print(find_nodes)
for i in range(len(find_nodes)):
    start_time = tm.time()
    for node in find_nodes[:i+1]:
        tm.sleep(0.000000001)
        dfs('S', node, balanced_tree)
    exec_time_dfs_bt.append(tm.time() - start_time)

print(exec_time_dfs_bt)
print(no_of_nodes)
    
plt.plot(no_of_nodes, exec_time_dfs_bt)
plt.xlabel("no of nodes to find")
plt.ylabel("time (seconds)")
plt.show()

table = pd.DataFrame(data=no_of_nodes, columns=['No_nodes'])
table['time (seconds)'] = exec_time_dfs_bt
print(table)
# Out:
# ['K', 'I', 'G', 'P', 'R', 'O', 'F', 'C', 'M', 'Q']
# [0.013002395629882812, 0.030847549438476562, 0.04787707328796387, 0.06206154823303223, 0.07642722129821777, 0.09381747245788574, 0.11054039001464844, 0.12437248229980469, 0.1400585174560547, 0.15689444541931152]
# range(1, 11)
#    No_nodes  time (seconds)
# 0         1        0.013002
# 1         2        0.030848
# 2         3        0.047877
# 3         4        0.062062
# 4         5        0.076427
# 5         6        0.093817
# 6         7        0.110540
# 7         8        0.124372
# 8         9        0.140059
# 9        10        0.156894

# %%
exec_time_bfs_bt = []
no_of_nodes = range(1, len(find_nodes)+1)

print(find_nodes)
for i in range(len(find_nodes)):
    start_time = tm.time()
    for node in find_nodes[:i+1]:
        tm.sleep(0.000000001)
        dfs('S', node, balanced_tree)
    exec_time_bfs_bt.append(tm.time() - start_time)

print(exec_time_bfs_bt)
print(no_of_nodes)
    
plt.plot(no_of_nodes, exec_time_bfs_bt)
plt.xlabel("no of nodes to find")
plt.ylabel("time (seconds)")
plt.show()

table = pd.DataFrame(data=no_of_nodes, columns=['No_nodes'])
table['time (seconds)'] = exec_time_bfs_bt
print(table)
# Out:
# ['K', 'I', 'G', 'P', 'R', 'O', 'F', 'C', 'M', 'Q']
# [0.009041309356689453, 0.03191256523132324, 0.04682469367980957, 0.06188058853149414, 0.07797098159790039, 0.09221959114074707, 0.11063671112060547, 0.12637567520141602, 0.1407020092010498, 0.1580801010131836]
# range(1, 11)
#    No_nodes  time (seconds)
# 0         1        0.009041
# 1         2        0.031913
# 2         3        0.046825
# 3         4        0.061881
# 4         5        0.077971
# 5         6        0.092220
# 6         7        0.110637
# 7         8        0.126376
# 8         9        0.140702
# 9        10        0.158080

# %%
plt.plot(no_of_nodes, exec_time_dfs_bt)
plt.plot(no_of_nodes, exec_time_bfs_bt)

plt.legend(['dfs for bal. tree', 'bfs for bal. tree'])
plt.xlabel("array length")
plt.ylabel("time (seconds)")
plt.show()

# %% [markdown]
# ### Run dfs and bfs on unbalanced tree

# %%
exec_time_dfs_ubt = []
no_of_nodes = range(1, len(find_nodes)+1)

print(find_nodes)
for i in range(len(find_nodes)):
    start_time = tm.time()
    for node in find_nodes[:i+1]:
        tm.sleep(0.000000001)
        dfs('S', node, unbalanced_tree)
    exec_time_dfs_ubt.append(tm.time() - start_time)

print(exec_time_dfs_ubt)
print(no_of_nodes)
    
plt.plot(no_of_nodes, exec_time_dfs_ubt)
plt.xlabel("no of nodes to find")
plt.ylabel("time (seconds)")
plt.show()

table = pd.DataFrame(data=no_of_nodes, columns=['No_nodes'])
table['time (seconds)'] = exec_time_dfs_ubt
print(table)
# Out:
# ['K', 'I', 'G', 'P', 'R', 'O', 'F', 'C', 'M', 'Q']
# [0.005980491638183594, 0.031893253326416016, 0.04681754112243652, 0.06222701072692871, 0.0766146183013916, 0.09161806106567383, 0.10857844352722168, 0.1262807846069336, 0.13991689682006836, 0.15523195266723633]
# range(1, 11)
#    No_nodes  time (seconds)
# 0         1        0.005980
# 1         2        0.031893
# 2         3        0.046818
# 3         4        0.062227
# 4         5        0.076615
# 5         6        0.091618
# 6         7        0.108578
# 7         8        0.126281
# 8         9        0.139917
# 9        10        0.155232

# %%
exec_time_bfs_ubt = []
no_of_nodes = range(1, len(find_nodes)+1)

print(find_nodes)
for i in range(len(find_nodes)):
    start_time = tm.time()
    for node in find_nodes[:i+1]:
        tm.sleep(0.000000001)
        bfs('S', node, unbalanced_tree)
    exec_time_bfs_ubt.append(tm.time() - start_time)

print(exec_time_bfs_ubt)
print(no_of_nodes)
    
plt.plot(no_of_nodes, exec_time_bfs_ubt)
plt.xlabel("no of nodes to find")
plt.ylabel("time (seconds)")
plt.show()

table = pd.DataFrame(data=no_of_nodes, columns=['No_nodes'])
table['time (seconds)'] = exec_time_bfs_ubt
print(table)
# Out:
# ['K', 'I', 'G', 'P', 'R', 'O', 'F', 'C', 'M', 'Q']
# [0.015964269638061523, 0.030919551849365234, 0.0464935302734375, 0.06250882148742676, 0.07839679718017578, 0.0925590991973877, 0.10950970649719238, 0.12589597702026367, 0.14237689971923828, 0.15568876266479492]
# range(1, 11)
#    No_nodes  time (seconds)
# 0         1        0.015964
# 1         2        0.030920
# 2         3        0.046494
# 3         4        0.062509
# 4         5        0.078397
# 5         6        0.092559
# 6         7        0.109510
# 7         8        0.125896
# 8         9        0.142377
# 9        10        0.155689

# %%
plt.plot(no_of_nodes, exec_time_dfs_ubt)
plt.plot(no_of_nodes, exec_time_bfs_ubt)

plt.legend(['dfs for unbal. tree', 'bfs for unbal. tree'])
plt.xlabel("array length")
plt.ylabel("time (seconds)")
plt.show()

# %%
find_nodes_test = r.sample(nodes_test, 100)

exec_time_dfs_test = []
no_of_nodes = range(1, len(find_nodes_test)+1)

print(find_nodes_test)
for i in range(len(find_nodes_test)):
    start_time = tm.time()
    tm.sleep(0.0000001)
    for node in find_nodes_test[:i+1]:
        ret = dfs('S', node, test_tree)
        
    exec_time_dfs_test.append(tm.time() - start_time)

print(exec_time_dfs_test)
print(no_of_nodes)
    
plt.plot(no_of_nodes, exec_time_dfs_test)
plt.xlabel("no of nodes to find")
plt.ylabel("time (seconds)")
plt.show()

table = pd.DataFrame(data=no_of_nodes, columns=['No_nodes'])
table['time (seconds)'] = exec_time_dfs_test
print(table)
# Out:
# ['S', 'Z', 'J', 'BZ', 'BM', 'AF', 'AK', 'BB', 'E', 'C', 'L', 'BQ', 'AG', 'M', 'I', 'AQ', 'AC', 'CQ', 'AU', 'CF', 'AL', 'AB', 'BY', 'AW', 'K', 'BF', 'AO', 'CB', 'W', 'CW', 'CD', 'D', 'BK', 'AV', 'AM', 'CJ', 'BV', 'AA', 'CH', 'V', 'BR', 'AN', 'U', 'CG', 'CS', 'BP', 'BO', 'A', 'X', 'N', 'P', 'AH', 'CN', 'CO', 'CX', 'CM', 'BG', 'AX', 'CE', 'R', 'B', 'BT', 'BU', 'BI', 'BJ', 'AT', 'O', 'CV', 'AD', 'AR', 'AE', 'AJ', 'AI', 'AS', 'BE', 'BL', 'BS', 'Y', 'BX', 'Q', 'BD', 'BC', 'BN', 'AZ', 'AY', 'G', 'BH', 'BA', 'CI', 'CT', 'CC', 'CP', 'CL', 'CA', 'CU', 'CR', 'F', 'CK', 'T', 'BW']
# [0.006132364273071289, 0.015842437744140625, 0.01589488983154297, 0.01599597930908203, 0.014900445938110352, 0.015540599822998047, 0.01539301872253418, 0.01600027084350586, 0.01494741439819336, 0.01474308967590332, 0.015195846557617188, 0.015264511108398438, 0.015549659729003906, 0.01575636863708496, 0.015476703643798828, 0.01515340805053711, 0.015210151672363281, 0.015705347061157227, 0.015532970428466797, 0.015649795532226562, 0.015467405319213867, 0.016082763671875, 0.015933752059936523, 0.015611648559570312, 0.01535654067993164, 0.015423297882080078, 0.015434741973876953, 0.015854597091674805, 0.015272855758666992, 0.015918731689453125, 0.015378713607788086, 0.015062093734741211, 0.015284299850463867, 0.01516866683959961, 0.015672922134399414, 0.01551675796508789, 0.015527963638305664, 0.015564918518066406, 0.015498161315917969, 0.015961647033691406, 0.01594376564025879, 0.015946626663208008, 0.015150785446166992, 0.015157461166381836, 0.015417337417602539, 0.015957117080688477, 0.015232563018798828, 0.015360593795776367, 0.01529240608215332, 0.015779733657836914, 0.015160083770751953, 0.016039371490478516, 0.015353918075561523, 0.015473127365112305, 0.015920162200927734, 0.015284061431884766, 0.015545129776000977, 0.01584005355834961, 0.015655994415283203, 0.01563119888305664, 0.015229225158691406, 0.015601158142089844, 0.015531301498413086, 0.015454530715942383, 0.015737533569335938, 0.015338659286499023, 0.015914201736450195, 0.015129327774047852, 0.016095638275146484, 0.015810012817382812, 0.015807390213012695, 0.015993118286132812, 0.015897512435913086, 0.01594686508178711, 0.015946388244628906, 0.015946626663208008, 0.01604175567626953, 0.015884876251220703, 0.015951871871948242, 0.014942169189453125, 0.015949249267578125, 0.015666961669921875, 0.015677928924560547, 0.015151500701904297, 0.01541590690612793, 0.015410900115966797, 0.015341997146606445, 0.015270471572875977, 0.015465497970581055, 0.015001058578491211, 0.0156252384185791, 0.01504969596862793, 0.015435457229614258, 0.0159456729888916, 0.015520095825195312, 0.01587390899658203, 0.01594853401184082, 0.014948606491088867, 0.01594829559326172, 0.015988588333129883]
# range(1, 101)
#     No_nodes  time (seconds)
# 0          1        0.006132
# 1          2        0.015842
# 2          3        0.015895
# 3          4        0.015996
# 4          5        0.014900
# ..       ...             ...
# 95        96        0.015874
# 96        97        0.015949
# 97        98        0.014949
# 98        99        0.015948
# 99       100        0.015989
#
# [100 rows x 2 columns]

# %%
exec_time_bfs_test = []

print(find_nodes_test)
for i in range(len(find_nodes_test)):
    start_time = tm.time()
    tm.sleep(0.0000001)
    for node in find_nodes_test[:i+1]:
        ret = bfs('S', node, test_tree)
        
    exec_time_bfs_test.append(tm.time() - start_time)

print(exec_time_bfs_test)
print(no_of_nodes)
    
plt.plot(no_of_nodes, exec_time_bfs_test)
plt.xlabel("no of nodes to find")
plt.ylabel("time (seconds)")
plt.show()

table = pd.DataFrame(data=no_of_nodes, columns=['No_nodes'])
table['time (seconds)'] = exec_time_bfs_test
print(table)
# Out:
# ['S', 'Z', 'J', 'BZ', 'BM', 'AF', 'AK', 'BB', 'E', 'C', 'L', 'BQ', 'AG', 'M', 'I', 'AQ', 'AC', 'CQ', 'AU', 'CF', 'AL', 'AB', 'BY', 'AW', 'K', 'BF', 'AO', 'CB', 'W', 'CW', 'CD', 'D', 'BK', 'AV', 'AM', 'CJ', 'BV', 'AA', 'CH', 'V', 'BR', 'AN', 'U', 'CG', 'CS', 'BP', 'BO', 'A', 'X', 'N', 'P', 'AH', 'CN', 'CO', 'CX', 'CM', 'BG', 'AX', 'CE', 'R', 'B', 'BT', 'BU', 'BI', 'BJ', 'AT', 'O', 'CV', 'AD', 'AR', 'AE', 'AJ', 'AI', 'AS', 'BE', 'BL', 'BS', 'Y', 'BX', 'Q', 'BD', 'BC', 'BN', 'AZ', 'AY', 'G', 'BH', 'BA', 'CI', 'CT', 'CC', 'CP', 'CL', 'CA', 'CU', 'CR', 'F', 'CK', 'T', 'BW']
# [0.007958650588989258, 0.016081571578979492, 0.015381813049316406, 0.01592087745666504, 0.016017913818359375, 0.015308141708374023, 0.015419960021972656, 0.01599407196044922, 0.015511035919189453, 0.015848875045776367, 0.015458822250366211, 0.015523910522460938, 0.01588129997253418, 0.015438079833984375, 0.015495538711547852, 0.015499353408813477, 0.016302824020385742, 0.016075611114501953, 0.015365362167358398, 0.015576839447021484, 0.015213727951049805, 0.01596355438232422, 0.015340805053710938, 0.015636920928955078, 0.016137123107910156, 0.015488386154174805, 0.01593303680419922, 0.015538215637207031, 0.015438079833984375, 0.01582050323486328, 0.015636920928955078, 0.015337228775024414, 0.015661954879760742, 0.016022920608520508, 0.015091180801391602, 0.015430212020874023, 0.015074014663696289, 0.015446662902832031, 0.015506982803344727, 0.015256404876708984, 0.015596866607666016, 0.015551567077636719, 0.015608072280883789, 0.01534414291381836, 0.016022443771362305, 0.015887737274169922, 0.014986991882324219, 0.015555143356323242, 0.015107870101928711, 0.015598773956298828, 0.015162467956542969, 0.016168832778930664, 0.01565861701965332, 0.015879154205322266, 0.015106201171875, 0.015870094299316406, 0.01546478271484375, 0.0157930850982666, 0.015840530395507812, 0.015558242797851562, 0.015678882598876953, 0.015709400177001953, 0.01531529426574707, 0.016069412231445312, 0.015308380126953125, 0.015405416488647461, 0.01572871208190918, 0.015342473983764648, 0.015907764434814453, 0.015674591064453125, 0.015607595443725586, 0.016002178192138672, 0.01625537872314453, 0.01596236228942871, 0.01592230796813965, 0.01645684242248535, 0.015605926513671875, 0.015616178512573242, 0.01577162742614746, 0.01550436019897461, 0.01597452163696289, 0.01533961296081543, 0.015065431594848633, 0.015595436096191406, 0.015490531921386719, 0.015673160552978516, 0.01556706428527832, 0.015715360641479492, 0.015485525131225586, 0.01610589027404785, 0.015900611877441406, 0.015320062637329102, 0.015715360641479492, 0.015547990798950195, 0.015595436096191406, 0.01590561866760254, 0.01548457145690918, 0.015845298767089844, 0.015488147735595703, 0.015512943267822266]
# range(1, 101)
#     No_nodes  time (seconds)
# 0          1        0.007959
# 1          2        0.016082
# 2          3        0.015382
# 3          4        0.015921
# 4          5        0.016018
# ..       ...             ...
# 95        96        0.015906
# 96        97        0.015485
# 97        98        0.015845
# 98        99        0.015488
# 99       100        0.015513
#
# [100 rows x 2 columns]

# %%
plt.plot(no_of_nodes, exec_time_dfs_test)
plt.plot(no_of_nodes, exec_time_bfs_test)

plt.legend(['dfs for a big unbal. tree', 'bfs for a big unbal. tree'])
plt.xlabel("array length")
plt.ylabel("time (seconds)")
plt.show()
